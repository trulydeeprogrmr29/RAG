# %% [markdown]
# ### DATA INGESTION

# %%
from langchain_core.documents import Document

# %%
from langchain_core.documents import Document
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "page":1,
        'author':"Deepak Chaudhary",
        "date_created":"2025-12-17"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'page': 1, 'author': 'Deepak Chaudhary', 'date_created': '2025-12-17'}, page_content='this is the main text content I am using to create RAG')

# %%
## create  a simple text file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_text={
    "../data/text_files/machine_learning.txt":"""Machine Learning Fundamentals


Machine Learning (ML) is a subset of artificial intelligence that enables systems to learn and improve from experience without being explicitly programmed. ML algorithms build mathematical models based on sample data, known as training data, to make predictions or decisions.

Key Concepts:
1. Supervised Learning: The algorithm learns from labeled training data
   - Examples: Classification, Regression
   - Common algorithms: Linear Regression, Random Forest, SVM

2. Unsupervised Learning: The algorithm finds patterns in unlabeled data
   - Examples: Clustering, Dimensionality Reduction
   - Common algorithms: K-Means, PCA

3. Reinforcement Learning: The algorithm learns through trial and error using rewards
   - Examples: Game playing, Robotics
   - Common algorithm: Q-Learning

Popular ML Libraries:
- Scikit-learn: Traditional ML algorithms
- TensorFlow: Deep learning framework by Google
- PyTorch: Deep learning framework by Facebook

Applications:
- Image recognition
- Natural language processing
- Recommendation systems
- Fraud detection""",


"../data/text_files/intro_python.txt":"""Introduction to Python Programming

Python is a high-level, interpreted programming language known for its simplicity and readability. Created by Guido van Rossum and first released in 1991, Python has become one of the most popular programming languages worldwide.

Why Learn Python?
Easy to learn and read
 Extensive libraries and frameworks
 Cross-platform compatibility
 Strong community support
 Versatile (Web, Data Science, AI, Automation)

Next Steps:
- Learn functions and modules
- Explore Python standard library
- Try popular frameworks like Django or Flask
- Practice with real projects"""
}
for filepath,content in sample_text.items():
    with open(filepath ,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample text files created")
# Out:
# Sample text files created

# %%
###TextLoader
#from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/intro_python.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/intro_python.txt'}, page_content='Introduction to Python Programming\n\nPython is a high-level, interpreted programming language known for its simplicity and readability. Created by Guido van Rossum and first released in 1991, Python has become one of the most popular programming languages worldwide.\n\nWhy Learn Python?\nEasy to learn and read\n Extensive libraries and frameworks\n Cross-platform compatibility\n Strong community support\n Versatile (Web, Data Science, AI, Automation)\n\nNext Steps:\n- Learn functions and modules\n- Explore Python standard library\n- Try popular frameworks like Django or Flask\n- Practice with real projects')]

# %%
##Directory loader
from langchain_community.document_loaders import DirectoryLoader,TextLoader

dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':"utf-8"},
    show_progress=False                                     )
document=dir_loader.load()
document
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\intro_python.txt'}, page_content='Introduction to Python Programming\n\nPython is a high-level, interpreted programming language known for its simplicity and readability. Created by Guido van Rossum and first released in 1991, Python has become one of the most popular programming languages worldwide.\n\nWhy Learn Python?\nEasy to learn and read\n Extensive libraries and frameworks\n Cross-platform compatibility\n Strong community support\n Versatile (Web, Data Science, AI, Automation)\n\nNext Steps:\n- Learn functions and modules\n- Explore Python standard library\n- Try popular frameworks like Django or Flask\n- Practice with real projects'),
# ...

# %%
##Directory loader
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", # Pattern to amtch Files
    loader_cls=PyMuPDFLoader, # loader class to use
    show_progress=False  
)
pdf_document=dir_loader.load()
pdf_document
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-12-17T05:34:50+00:00', 'source': '..\\data\\pdf\\attention.pdf', 'file_path': '..\\data\\pdf\\attention.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2025-12-17T05:34:50+00:00', 'trapped': '', 'modDate': "D:20251217053450+00'00'", 'creationDate': "D:20251217053450+00'00'", 'page': 0}, page_content='This document explains the attention mechanism used in modern deep learning models. Attention\nallows neural networks to dynamically focus on the most relevant parts of the input data. It\nsignificantly improves performance in tasks such as machine translation, text summarization, and\nquestion answering. Self-attention is the core idea behind Transformer models like BERT and GPT,\nenabling parallel processing and better context understanding.'),
# ...

# %%
type(pdf_document[0])
# Out:
# langchain_core.documents.base.Document
